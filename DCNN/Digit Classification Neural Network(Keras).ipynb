# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.layers import Input, Flatten, Dense

# data
from tensorflow.keras.datasets import mnist

# %% [markdown]
# ## Load data

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train[i+50], cmap='gray')
    plt.title(y_train[i+50])

# %%
model = keras.Sequential([
    Input(shape=(28, 28)),
    Flatten(),
    Dense(105, activation='relu'),
    Dense(10, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_7 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 105)                 │          82,425 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 10)                  │           1,060 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 83,485 (326.11 KB)
#  Trainable params: 83,485 (326.11 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
x_train = x_train / 255
x_test = x_test / 255

# %%
y_train_cat = keras.utils.to_categorical(y_train, 10)
y_test_cat = keras.utils.to_categorical(y_test, 10)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train_cat, batch_size=32, epochs=10, validation_split=.2)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9171 - loss: 0.2971 - val_accuracy: 0.9542 - val_loss: 0.1621
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9609 - loss: 0.1344 - val_accuracy: 0.9638 - val_loss: 0.1255
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9725 - loss: 0.0938 - val_accuracy: 0.9703 - val_loss: 0.1053
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9794 - loss: 0.0711 - val_accuracy: 0.9705 - val_loss: 0.0993
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9835 - loss: 0.0559 - val_accuracy: 0.9737 - val_loss: 0.0903
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9861 - loss: 0.0436 - val_accuracy: 0.9721 - val_loss: 0.0935
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9898 - loss: 0.0347 - val_accuracy: 0.9728 - val_loss: 0.0937
# Epoch 8/10
# ...

# %%
model.evaluate(x_test, y_test_cat)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9782 - loss: 0.0801
# [0.08005782216787338, 0.9782000184059143]

# %%
import cv2

# %%
_1 = cv2.imread(r'img/2_1.png')
# _7 = cv2.imread(r"img/1_7.png'.png")

type(_1)

# _1 = cv2.cvtColor(_1, cv2.COLOR_RGB2GRAY)
# _7 = cv2.cvtColor(_7, cv2.COLOR_BGR2GRAY)

# _1 = cv2.resize(_1, (28, 28))
# _7 = cv2.resize(_7, (28, 28))

# _1 = _1 / 255.0
# _7 = _7 / 255.0

# r_1 = _1.reshape(1, 28, 28)
# r_7 = _7.reshape(1, 28, 28)

# r_1 = np.array(r_1, dtype=np.float32)
# r_7 = np.array(r_7, dtype=np.float32)


# plt.imshow(_1);
# plt.imshow(_1, cmap='gray');
# Out:
# NoneType

# %%
pred = model.predict(r_7)
print(pred)
print(np.argmax(pred))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# [[1.2344747e-19 1.2933812e-37 8.4212683e-03 4.7083995e-13 1.6930517e-35
#   2.3047994e-07 9.9157846e-01 1.5581282e-15 1.7114815e-11 2.5480098e-26]]
# 6
